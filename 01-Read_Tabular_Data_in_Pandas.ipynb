# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdalrahmanhassan237/Pandas-Tutorials-for-Data-Analysis/blob/master/Read_Tabular_Data_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Read Tabular Data File in Pandas

# %%
import pandas as pd

# %%
dataset =  pd.read_table('https://bit.ly/chiporders')

# %%
dataset.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # we solve three problems
# * seperate columns
# * not taking first row as columns of data as columns name
# * create our column names using list

# %%
user_colums = ['user_id','age','gender','occupation','zip_code']
data_2 = pd.read_table('https://bit.ly/movieusers',sep= '|' , header = None , names = user_colums)
data_2.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213
